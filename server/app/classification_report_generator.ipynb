# %%
import os
import sys
from pathlib import Path
from typing import Optional

import pandas as pd

# Add server root to path and import ONLY standalone benchmark module.
server_root = Path.cwd().resolve().parent if Path.cwd().name == "app" else Path.cwd().resolve()
if str(server_root) not in sys.path:
    sys.path.insert(0, str(server_root))

from benchmark.plantdoc_classification_report import (
    run_benchmark,
)

pd.set_option("display.max_columns", None)
pd.set_option("display.width", 180)

# %% [markdown]
# # PlantDoc Classification Report with LangChain + OpenRouter
#
# This notebook documents the real benchmark pipeline used for PlantDoc evaluation:
# - Real PlantDoc test images loaded from the filesystem
# - Parallel vision inference through LangChain + OpenRouter
# - Final synthesis and validation with a verifier model
# - Classification report, confusion matrix, and per-class analysis artifacts

# %%
import os
import sys
from pathlib import Path
from typing import Optional

import pandas as pd
from dotenv import load_dotenv

# Add server root to path and import the standalone benchmark pipeline.
server_root = Path.cwd().resolve().parent if Path.cwd().name == "app" else Path.cwd().resolve()
if str(server_root) not in sys.path:
    sys.path.insert(0, str(server_root))

from benchmark.plantdoc_classification_report import run_benchmark

load_dotenv()
OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
if not OPENROUTER_API_KEY:
    raise RuntimeError("OPENROUTER_API_KEY not found. Please set it in server/.env")

# Real PlantDoc test dataset directory
DATASET_TEST_DIR = Path("dataset/plantdoc/test")
# Optional cap for quick smoke runs
MAX_IMAGES: Optional[int] = None

pd.set_option("display.max_columns", None)
pd.set_option("display.width", 180)

print(f"PlantDoc test directory: {DATASET_TEST_DIR}")
print("Benchmark pipeline: LangChain + OpenRouter vision ensemble")

# %%
# Real benchmark pipeline
# The notebook delegates the full evaluation flow to the standalone benchmark module.
# Run the setup cell above, then execute the helper below to generate the report artifacts.
print("Real benchmark pipeline ready.")

# %% [markdown]
# ## Report Output
#
# The report is generated from real PlantDoc test data and should be interpreted as a live benchmark artifact, not a synthetic simulation.

# %% [markdown]
# ## Batch Processing (Minimal Output)
#
# Analyze multiple images with minimal output only:
# - batch_analyze_images(): returns plant_name and disease
# - generate_analysis_report(): lightweight success + disease breakdown
# - plot_disease_summary(): simple disease distribution chart

# %%
def run_notebook_benchmark(
    dataset_test_dir: Path,
    output_dir: Path = Path("benchmark_outputs"),
    max_images: Optional[int] = None,
):
    metrics = run_benchmark(
        dataset_test_dir=dataset_test_dir,
        output_dir=output_dir,
        max_images=max_images,
    )

    report_df = pd.read_csv(Path(metrics["report_csv"]))
    preds_df = pd.read_csv(Path(metrics["predictions_csv"]))

    return metrics, report_df, preds_df


print("Notebook helper ready: run_notebook_benchmark()")

# %% [markdown]
# ## Quick Start
#
# Run the notebook helper against the PlantDoc test directory to generate the real benchmark report and the associated LangChain/OpenRouter outputs.

# %%
dataset_test_dir = DATASET_TEST_DIR
output_dir = Path("benchmark_outputs")

metrics, report_df, preds_df = run_notebook_benchmark(
    dataset_test_dir=dataset_test_dir,
    output_dir=output_dir,
    max_images=MAX_IMAGES,
)

print(metrics)
report_df.head(20)
